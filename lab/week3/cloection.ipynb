# %% [markdown]
# typle,set dictionary 실습

# %% [markdown]
# byte, bytes, bytearray 공부

# %% [markdown]
# all 과 len

# %%
cap = {}
cap["Korea"] = "Seoul"
cap["USA"] = "Washington"
cap["UK"] = "London"
cap["France"] = "Paris"

print(cap)
# Out:
# {'Korea': 'Seoul', 'USA': 'Washington', 'UK': 'London', 'France': 'Paris'}
