# %% [markdown]
# ## List 연습 노트 파일입니다.

# %% [markdown]
# 리스트의 합병 연산(*)
# 리스트의 곱 연산(*)

# %%
fruit = []
fruit.append("사과")
fruit.append("바나나")
print(fruit)
# Out:
# ['사과', '바나나']

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
print(list1 <= list2)
# Out:
# True
